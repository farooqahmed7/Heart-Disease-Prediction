# %% [markdown]
# # **Heart Disease Prediction**.

# %% [markdown]
# # Project Summary
# ## Requirement :
# Heart disease is the number one cause of death worldwide.Preventing heart disease is important. Good data-driven systems for   predicting heart disease can improve the entire research and prevention process, making sure that more people can live         healthy lives.
# In the United States, the Centers for Disease Control and Prevention is a good resource for information about heart disease.   According to their website
# - About 610,000 people die of heart disease in the United States every year–that’s 1 in every 4 deaths.
# - Heart disease is the leading cause of death for both men and women. More than half of the deaths due to heart disease in 2009   were in men.
# - Coronary heart disease (CHD) is the most common type of heart disease, killing over 370,000 people annually.
# - Every year about 735,000 Americans have a heart attack. Of these, 525,000 are a first heart attack and 210,000 happen in       people who have already had a heart attack.
# - Heart disease is the leading cause of death for people of most ethnicities in the United States, including African Americans,   Hispanics, and whites. For American Indians or Alaska Natives and Asians or Pacific Islanders, heart disease is second only     to cancer.
#
#
# The goal is to predict the binary class heart_disease_present, which represents whether or not a patient has heart disease:
# - 0 represents no heart disease present
# - 1 represents heart disease present
#
# ## Analysis:
#
# - The data obtained is cleaned, supervised and categorical data. The Dependent variable is 'heart_disease_present', the raw       data obtained was having 180 rows and 15 columns. To analyze this, Correlation between independent features and even with       respect to target variable is used, along with this Pandas_Profiling is done to the entire dataset to understand each and       every feature. Label Encoding and Scaling of the dataset has been done. The features has been finalized based on Correlation   between variables and feature_importances of the model.
# - After Exploratory Data Analysis, the finalized features are 'slope_of_peak_exercise_st_segment',   'thal', 'resting_blood_pressure',  'chest_pain_type',  'num_major_vessels',  'serum_cholesterol_mg_per_dl',  'oldpeak_eq_st_depression',  'sex',  'age',  'max_heart_rate_achieved',  'exercise_induced_angina',
# - The algorithms used are Logistic Regression, Random Forest Classifier. K-Fold cross_validation technique is also applied to the    model.
#
# ## Summary :
#
# The main aim of doing the project is to predict whether or not a patient has heart disease. The key steps followed during analysis are
# - Importing the raw data provided, classified the features as independent and target variable. Exploratory Data Analysis is       carried out.
# - Pandas_Profiling is done to understand each feature of the dataset.
# - Label Encoding is done for the ordinal variables of the dataset.
# - For training and testing the algorithms used were, Logistic Regression and Random Forest and also checked which algorithm       provides the better accuracy_score for the model. K-Fold cross_validation Technique has also been applied.
#
# ## Results :
# The following accuracy_scores have been obtained from different algorithms :
# - Logistic Regression       = 82.35%
# - Random Forest Classifier  = 85.71%
#
# #### Random Forest Classifier with 10 k_fold cross_validation, the accuracy_score was 100%. Along with this, the precision, recall,              f1_score were also  100%.

# %%
# Importing the Required Packages.
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sb
sb.set_style("whitegrid")

pd.options.display.max_columns=20
pd.options.display.max_rows=200

import warnings
warnings.filterwarnings('ignore')
# Out:
# In C:\Users\aptit\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The text.latex.preview rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\Users\aptit\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The mathtext.fallback_to_cm rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\Users\aptit\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle: Support for setting the 'mathtext.fallback_to_cm' rcParam is deprecated since 3.3 and will be removed two minor releases later; use 'mathtext.fallback : 'cm' instead.
# In C:\Users\aptit\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The validate_bool_maybe_none function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# ...

# %% [markdown]
# ### Importing the Data.

# %%
heart_1=pd.read_csv('heart_data.csv')
heart_1
# Out:
#     patient_id  slope_of_peak_exercise_st_segment               thal  \
# 0       0z64un                                  1             normal
# 1       ryoo3j                                  2             normal
# 2       yt1s1x                                  1             normal
# 3       l2xjde                                  1  reversible_defect
# 4       oyt4ek                                  3  reversible_defect
# 5       ldukkw                                  1             normal
# 6       2gbyh9                                  2  reversible_defect
# 7       daa9kp                                  2       fixed_defect
# 8       3nwy2n                                  3  reversible_defect
# 9       1r508r                                  2             normal
# 10      ldg4b9                                  2             normal
# 11      xc17yq                                  1             normal
# 12      mpggsq                                  1             normal
# ...

# %%
heart_1.shape
# Out:
# (180, 14)

# %%
heart_target=pd.read_csv('heart_data_target.csv')
heart_target
# Out:
#     patient_id  heart_disease_present
# 0       0z64un                      0
# 1       ryoo3j                      0
# 2       yt1s1x                      1
# 3       l2xjde                      1
# 4       oyt4ek                      0
# 5       ldukkw                      0
# 6       2gbyh9                      1
# 7       daa9kp                      1
# 8       3nwy2n                      1
# 9       1r508r                      0
# 10      ldg4b9                      0
# 11      xc17yq                      0
# 12      mpggsq                      1
# 13      zlyac8                      0
# 14      f06u72                      1
# 15      2fv3rc                      1
# 16      qyrkxn                      0
# 17      237mql                      1
# 18      mc750a                      0
# 19      30v796                      1
# 20      cvux3j                      0
# 21      k8899q                      0
# 22      jhdvtb                      0
# 23      5g9v0h                      0
# ...

# %%
heart_target.shape
# Out:
# (180, 2)

# %%
heart=heart_1.merge(heart_target,left_on='patient_id',right_on='patient_id')
heart
# Out:
#     patient_id  slope_of_peak_exercise_st_segment               thal  \
# 0       0z64un                                  1             normal
# 1       ryoo3j                                  2             normal
# 2       yt1s1x                                  1             normal
# 3       l2xjde                                  1  reversible_defect
# 4       oyt4ek                                  3  reversible_defect
# 5       ldukkw                                  1             normal
# 6       2gbyh9                                  2  reversible_defect
# 7       daa9kp                                  2       fixed_defect
# 8       3nwy2n                                  3  reversible_defect
# 9       1r508r                                  2             normal
# 10      ldg4b9                                  2             normal
# 11      xc17yq                                  1             normal
# 12      mpggsq                                  1             normal
# ...

# %% [markdown]
# # Exploratory Data Analysis(EDA).

# %% [markdown]
# ## Pandas Profiling

# %%
from pandas_profiling import ProfileReport

# %%
profile=ProfileReport(heart, title="Profiling Report",explorative =True)

# %%
#profile.to_widgets()

# %%
#profile.to_file('Heart Disease Pandas Profiling.html')

# %%
# To check the shape of the dataset.
heart.shape
# Out:
# (180, 15)

# %%
# To Check if there are any missing values in the dataset.
heart.isnull().sum()
# Out:
# patient_id                              0
# slope_of_peak_exercise_st_segment       0
# thal                                    0
# resting_blood_pressure                  0
# chest_pain_type                         0
# num_major_vessels                       0
# fasting_blood_sugar_gt_120_mg_per_dl    0
# resting_ekg_results                     0
# serum_cholesterol_mg_per_dl             0
# oldpeak_eq_st_depression                0
# sex                                     0
# age                                     0
# max_heart_rate_achieved                 0
# exercise_induced_angina                 0
# heart_disease_present                   0
# dtype: int64

# %%
# Features of the dataset.
heart.keys()
# Out:
# Index(['patient_id', 'slope_of_peak_exercise_st_segment', 'thal',
#        'resting_blood_pressure', 'chest_pain_type', 'num_major_vessels',
#        'fasting_blood_sugar_gt_120_mg_per_dl', 'resting_ekg_results',
#        'serum_cholesterol_mg_per_dl', 'oldpeak_eq_st_depression', 'sex', 'age',
#        'max_heart_rate_achieved', 'exercise_induced_angina',
#        'heart_disease_present'],
#       dtype='object')

# %%
heart.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 180 entries, 0 to 179
# Data columns (total 15 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   patient_id                            180 non-null    object
#  1   slope_of_peak_exercise_st_segment     180 non-null    int64
#  2   thal                                  180 non-null    object
#  3   resting_blood_pressure                180 non-null    int64
#  4   chest_pain_type                       180 non-null    int64
#  5   num_major_vessels                     180 non-null    int64
#  6   fasting_blood_sugar_gt_120_mg_per_dl  180 non-null    int64
#  7   resting_ekg_results                   180 non-null    int64
#  8   serum_cholesterol_mg_per_dl           180 non-null    int64
#  9   oldpeak_eq_st_depression              180 non-null    float64
#  10  sex                                   180 non-null    int64
# ...

# %%
# To View Statistics of the dataset
heart.describe(exclude=None)
# Out:
#        slope_of_peak_exercise_st_segment  resting_blood_pressure  \
# count                         180.000000              180.000000
# mean                            1.550000              131.311111
# std                             0.618838               17.010443
# min                             1.000000               94.000000
# 25%                             1.000000              120.000000
# 50%                             1.000000              130.000000
# 75%                             2.000000              140.000000
# max                             3.000000              180.000000
#
#        chest_pain_type  num_major_vessels  \
# count       180.000000         180.000000
# mean          3.155556           0.694444
# std           0.938454           0.969347
# min           1.000000           0.000000
# 25%           3.000000           0.000000
# 50%           3.000000           0.000000
# 75%           4.000000           1.000000
# ...

# %%
# To Check the  Correlation between the features with respect to the Target variable
heart.corr().heart_disease_present.sort_values(ascending=False)
# Out:
# heart_disease_present                   1.000000
# exercise_induced_angina                 0.448647
# num_major_vessels                       0.421519
# chest_pain_type                         0.412829
# oldpeak_eq_st_depression                0.382930
# slope_of_peak_exercise_st_segment       0.344224
# sex                                     0.335421
# resting_ekg_results                     0.145933
# age                                     0.138255
# serum_cholesterol_mg_per_dl             0.079775
# resting_blood_pressure                  0.078506
# fasting_blood_sugar_gt_120_mg_per_dl    0.003379
# max_heart_rate_achieved                -0.375352
# Name: heart_disease_present, dtype: float64

# %%
# To visualize the Correlation table for understanding its percentage coefficients.
plt.figure(figsize=(10,10))
sb.heatmap(heart.corr(),annot=True,fmt='.0%')
# Out:
# <AxesSubplot:>

# %%
# To check a pairwise relationships in a dataset.
sb.pairplot(heart,hue='heart_disease_present')

# %%
sb.countplot(heart.heart_disease_present)
# Out:
# <AxesSubplot:xlabel='heart_disease_present', ylabel='count'>

# %%
# To Find the number of unique values present in the each feature of the dataset.
heart.nunique()
# Out:
# patient_id                              180
# slope_of_peak_exercise_st_segment         3
# thal                                      3
# resting_blood_pressure                   36
# chest_pain_type                           4
# num_major_vessels                         4
# fasting_blood_sugar_gt_120_mg_per_dl      2
# resting_ekg_results                       3
# serum_cholesterol_mg_per_dl             118
# oldpeak_eq_st_depression                 34
# sex                                       2
# age                                      40
# max_heart_rate_achieved                  73
# exercise_induced_angina                   2
# heart_disease_present                     2
# dtype: int64

# %%
heart.keys()
# Out:
# Index(['patient_id', 'slope_of_peak_exercise_st_segment', 'thal',
#        'resting_blood_pressure', 'chest_pain_type', 'num_major_vessels',
#        'fasting_blood_sugar_gt_120_mg_per_dl', 'resting_ekg_results',
#        'serum_cholesterol_mg_per_dl', 'oldpeak_eq_st_depression', 'sex', 'age',
#        'max_heart_rate_achieved', 'exercise_induced_angina',
#        'heart_disease_present'],
#       dtype='object')

# %% [markdown]
# ## Features Exploration with Visualization.

# %%
heart.slope_of_peak_exercise_st_segment.value_counts()
# Out:
# 1    93
# 2    75
# 3    12
# Name: slope_of_peak_exercise_st_segment, dtype: int64

# %%
heart.slope_of_peak_exercise_st_segment.describe()
# Out:
# count    180.000000
# mean       1.550000
# std        0.618838
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        2.000000
# max        3.000000
# Name: slope_of_peak_exercise_st_segment, dtype: float64

# %%
sb.countplot(heart.slope_of_peak_exercise_st_segment)
# Out:
# <AxesSubplot:xlabel='slope_of_peak_exercise_st_segment', ylabel='count'>

# %%
sb.distplot(heart.slope_of_peak_exercise_st_segment)
sb.set_style("whitegrid")

# %%
heart.thal.describe()
# Out:
# count        180
# unique         3
# top       normal
# freq          98
# Name: thal, dtype: object

# %%
heart.thal.value_counts()
# Out:
# normal               98
# reversible_defect    74
# fixed_defect          8
# Name: thal, dtype: int64

# %%
sb.countplot(heart.thal)
# Out:
# <AxesSubplot:xlabel='thal', ylabel='count'>

# %%
heart.resting_blood_pressure.describe()
# Out:
# count    180.000000
# mean     131.311111
# std       17.010443
# min       94.000000
# 25%      120.000000
# 50%      130.000000
# 75%      140.000000
# max      180.000000
# Name: resting_blood_pressure, dtype: float64

# %%
sb.distplot(heart.resting_blood_pressure)
# Out:
# <AxesSubplot:xlabel='resting_blood_pressure', ylabel='Density'>

# %%
heart.chest_pain_type.describe()
# Out:
# count    180.000000
# mean       3.155556
# std        0.938454
# min        1.000000
# 25%        3.000000
# 50%        3.000000
# 75%        4.000000
# max        4.000000
# Name: chest_pain_type, dtype: float64

# %%
heart.chest_pain_type.value_counts()
# Out:
# 4    82
# 3    57
# 2    28
# 1    13
# Name: chest_pain_type, dtype: int64

# %%
sb.countplot(heart.chest_pain_type)
# Out:
# <AxesSubplot:xlabel='chest_pain_type', ylabel='count'>

# %%
sb.distplot(heart.chest_pain_type)
# Out:
# <AxesSubplot:xlabel='chest_pain_type', ylabel='Density'>

# %%
heart.num_major_vessels.describe()
# Out:
# count    180.000000
# mean       0.694444
# std        0.969347
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        3.000000
# Name: num_major_vessels, dtype: float64

# %%
heart.num_major_vessels.value_counts()
# Out:
# 0    106
# 1     37
# 2     23
# 3     14
# Name: num_major_vessels, dtype: int64

# %%
sb.countplot(heart.num_major_vessels)
# Out:
# <AxesSubplot:xlabel='num_major_vessels', ylabel='count'>

# %%
sb.distplot(heart.num_major_vessels)
# Out:
# <AxesSubplot:xlabel='num_major_vessels', ylabel='Density'>

# %%
heart.fasting_blood_sugar_gt_120_mg_per_dl.describe()
# Out:
# count    180.000000
# mean       0.161111
# std        0.368659
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000
# Name: fasting_blood_sugar_gt_120_mg_per_dl, dtype: float64

# %%
sb.countplot(heart.fasting_blood_sugar_gt_120_mg_per_dl)
# Out:
# <AxesSubplot:xlabel='fasting_blood_sugar_gt_120_mg_per_dl', ylabel='count'>

# %%
sb.distplot(heart.fasting_blood_sugar_gt_120_mg_per_dl)
# Out:
# <AxesSubplot:xlabel='fasting_blood_sugar_gt_120_mg_per_dl', ylabel='Density'>

# %%
heart.resting_ekg_results.describe()
# Out:
# count    180.000000
# mean       1.050000
# std        0.998742
# min        0.000000
# 25%        0.000000
# 50%        2.000000
# 75%        2.000000
# max        2.000000
# Name: resting_ekg_results, dtype: float64

# %%
sb.countplot(heart.resting_ekg_results)
# Out:
# <AxesSubplot:xlabel='resting_ekg_results', ylabel='count'>

# %%
sb.distplot(heart.resting_ekg_results)
# Out:
# <AxesSubplot:xlabel='resting_ekg_results', ylabel='Density'>

# %%
heart.serum_cholesterol_mg_per_dl.describe()
# Out:
# count    180.000000
# mean     249.211111
# std       52.717969
# min      126.000000
# 25%      213.750000
# 50%      245.500000
# 75%      281.250000
# max      564.000000
# Name: serum_cholesterol_mg_per_dl, dtype: float64

# %%
# This feature is having Outliers.
sb.distplot(heart.serum_cholesterol_mg_per_dl)
# Out:
# <AxesSubplot:xlabel='serum_cholesterol_mg_per_dl', ylabel='Density'>

# %%
heart.oldpeak_eq_st_depression.describe()
# Out:
# count    180.000000
# mean       1.010000
# std        1.121357
# min        0.000000
# 25%        0.000000
# 50%        0.800000
# 75%        1.600000
# max        6.200000
# Name: oldpeak_eq_st_depression, dtype: float64

# %%
# This feature is having Outliers.
sb.distplot(heart.oldpeak_eq_st_depression)
# Out:
# <AxesSubplot:xlabel='oldpeak_eq_st_depression', ylabel='Density'>

# %%
heart.sex.describe()
# Out:
# count    180.000000
# mean       0.688889
# std        0.464239
# min        0.000000
# 25%        0.000000
# 50%        1.000000
# 75%        1.000000
# max        1.000000
# Name: sex, dtype: float64

# %%
sb.distplot(heart.sex)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='Density'>

# %%
sb.countplot(heart.sex)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
heart.age.describe()
# Out:
# count    180.000000
# mean      54.811111
# std        9.334737
# min       29.000000
# 25%       48.000000
# 50%       55.000000
# 75%       62.000000
# max       77.000000
# Name: age, dtype: float64

# %%
sb.distplot(heart.age)
# Out:
# <AxesSubplot:xlabel='age', ylabel='Density'>

# %%
heart.max_heart_rate_achieved.describe()
# Out:
# count    180.000000
# mean     149.483333
# std       22.063513
# min       96.000000
# 25%      132.000000
# 50%      152.000000
# 75%      166.250000
# max      202.000000
# Name: max_heart_rate_achieved, dtype: float64

# %%
sb.distplot(heart.max_heart_rate_achieved)
# Out:
# <AxesSubplot:xlabel='max_heart_rate_achieved', ylabel='Density'>

# %%
heart.exercise_induced_angina.describe()
# Out:
# count    180.000000
# mean       0.316667
# std        0.466474
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        1.000000
# Name: exercise_induced_angina, dtype: float64

# %%
sb.countplot(heart.exercise_induced_angina)
# Out:
# <AxesSubplot:xlabel='exercise_induced_angina', ylabel='count'>

# %%
sb.distplot(heart.exercise_induced_angina)
# Out:
# <AxesSubplot:xlabel='exercise_induced_angina', ylabel='Density'>

# %%
heart.heart_disease_present.describe()
# Out:
# count    180.000000
# mean       0.444444
# std        0.498290
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        1.000000
# Name: heart_disease_present, dtype: float64

# %%
sb.distplot(heart.heart_disease_present)
# Out:
# <AxesSubplot:xlabel='heart_disease_present', ylabel='Density'>

# %%
sb.countplot(heart.heart_disease_present)
# Out:
# <AxesSubplot:xlabel='heart_disease_present', ylabel='count'>

# %% [markdown]
# # FEATURE ENGINEERING.

# %% [markdown]
# ## Dropping Features Based on Correlation.

# %%
plt.figure(figsize=(10,10))
sb.heatmap(heart.corr(),annot=True,fmt='.0%')
# Out:
# <AxesSubplot:>

# %%
heart.corr()['heart_disease_present'].sort_values(ascending=False)
# Out:
# heart_disease_present                   1.000000
# exercise_induced_angina                 0.448647
# num_major_vessels                       0.421519
# chest_pain_type                         0.412829
# oldpeak_eq_st_depression                0.382930
# slope_of_peak_exercise_st_segment       0.344224
# sex                                     0.335421
# resting_ekg_results                     0.145933
# age                                     0.138255
# serum_cholesterol_mg_per_dl             0.079775
# resting_blood_pressure                  0.078506
# fasting_blood_sugar_gt_120_mg_per_dl    0.003379
# max_heart_rate_achieved                -0.375352
# Name: heart_disease_present, dtype: float64

# %%
heart.drop(['patient_id'],axis=1,inplace=True)
# Neither correlated with input variables nor with target variable

# %%
heart.drop(['fasting_blood_sugar_gt_120_mg_per_dl'],axis=1,inplace=True)
# No correlation with Target.

# %%
heart.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 180 entries, 0 to 179
# Data columns (total 13 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   slope_of_peak_exercise_st_segment  180 non-null    int64
#  1   thal                               180 non-null    object
#  2   resting_blood_pressure             180 non-null    int64
#  3   chest_pain_type                    180 non-null    int64
#  4   num_major_vessels                  180 non-null    int64
#  5   resting_ekg_results                180 non-null    int64
#  6   serum_cholesterol_mg_per_dl        180 non-null    int64
#  7   oldpeak_eq_st_depression           180 non-null    float64
#  8   sex                                180 non-null    int64
#  9   age                                180 non-null    int64
#  10  max_heart_rate_achieved            180 non-null    int64
# ...

# %%
from sklearn.preprocessing import LabelEncoder
enc=LabelEncoder()
heart.thal=enc.fit_transform(heart.thal)

# %% [markdown]
# ### Skewness , Kurtosis & Z_score

# %%
from scipy import stats

# %%
# Skewness of the Target variable , to measure the symmetric .
print("skewness:" , stats.skew(heart.heart_disease_present)) # range -1<s<1
# Out:
# skewness: 0.22360679774997907

# %%
# Kurtosis of the Target Variable, to measure the tailedness(peakness) of the variable
print("kurtosis:" , stats.kurtosis(heart.heart_disease_present)) # range -1<k<1
# Out:
# kurtosis: -1.9500000000000002

# %%
#Skewness of the entire dataset.
pd.DataFrame(stats.skew(heart))
# Out:
#            0
# 0   0.660586
# 1  -0.197028
# 2   0.651592
# 3  -0.842165
# 4   1.158243
# 5  -0.100124
# 6   1.263291
# 7   1.494821
# 8  -0.816026
# 9  -0.197502
# 10 -0.390416
# 11  0.788232
# 12  0.223607

# %%
heart.serum_cholesterol_mg_per_dl.value_counts()
# Out:
# 204    4
# 239    4
# 219    3
# 254    3
# 309    3
# 226    3
# 303    3
# 211    3
# 282    3
# 233    3
# 234    3
# 256    3
# 263    3
# 277    2
# 265    2
# 203    2
# 199    2
# 197    2
# 188    2
# 177    2
# 258    2
# 149    2
# 330    2
# 308    2
# 283    2
# 266    2
# 304    2
# 267    2
# 302    2
# 299    2
# 269    2
# 270    2
# 273    2
# 274    2
# 294    2
# 255    2
# 212    2
# 223    2
# 230    2
# 243    2
# 244    2
# 245    2
# 229    2
# 228    2
# 246    2
# 250    2
# 214    2
# 227    1
# 286    1
# 305    1
# 300    1
# 225    1
# 224    1
# 311    1
# 298    1
# 295    1
# 231    1
# 293    1
# 290    1
# 289    1
# 281    1
# 564    1
# 248    1
# 253    1
# 259    1
# 261    1
# 262    1
# 252    1
# 249    1
# 268    1
# 232    1
# 271    1
# 275    1
# 276    1
# 236    1
# 235    1
# 315    1
# 313    1
# 319    1
# 210    1
# 198    1
# 185    1
# 217    1
# 192    1
# 193    1
# 195    1
# 196    1
# 216    1
# 215    1
# 218    1
# ...

# %%
heart.serum_cholesterol_mg_per_dl.describe()
# Out:
# count    180.000000
# mean     249.211111
# std       52.717969
# min      126.000000
# 25%      213.750000
# 50%      245.500000
# 75%      281.250000
# max      564.000000
# Name: serum_cholesterol_mg_per_dl, dtype: float64

# %%
# This feature is having Outlier.
sb.distplot(heart.serum_cholesterol_mg_per_dl)
# Out:
# <AxesSubplot:xlabel='serum_cholesterol_mg_per_dl', ylabel='Density'>

# %%
heart.num_major_vessels.value_counts()
# Out:
# 0    106
# 1     37
# 2     23
# 3     14
# Name: num_major_vessels, dtype: int64

# %%
heart.num_major_vessels.describe()
# Out:
# count    180.000000
# mean       0.694444
# std        0.969347
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        3.000000
# Name: num_major_vessels, dtype: float64

# %%
sb.set_style("whitegrid")
sb.distplot(heart.num_major_vessels)
# Out:
# <AxesSubplot:xlabel='num_major_vessels', ylabel='Density'>

# %%
heart.oldpeak_eq_st_depression.describe()
# Out:
# count    180.000000
# mean       1.010000
# std        1.121357
# min        0.000000
# 25%        0.000000
# 50%        0.800000
# 75%        1.600000
# max        6.200000
# Name: oldpeak_eq_st_depression, dtype: float64

# %%
sb.distplot(heart.oldpeak_eq_st_depression)
# Out:
# <AxesSubplot:xlabel='oldpeak_eq_st_depression', ylabel='Density'>

# %%
#Kurtosis of the entire Dataset
pd.DataFrame(stats.kurtosis(heart))
# Out:
#            0
# 0  -0.524274
# 1  -0.759402
# 2   0.426916
# 3  -0.303344
# 4   0.101055
# 5  -1.984360
# 6   6.155856
# 7   3.120266
# 8  -1.334101
# 9  -0.584858
# 10 -0.502808
# 11 -1.378691
# 12 -1.950000

# %% [markdown]
# ### To Remove Outliers using z_score.

# %%
# To check  the standard score is the number of standard deviations by which the value of a raw score is above or below the mean value.
z_scores=stats.zscore(heart)
heart_1=pd.DataFrame(z_scores)
heart_1
# Out:
#            0         1         2         3         4         5         6   \
# 0   -0.891241 -0.647059 -0.195195 -1.234775 -0.718403  0.953850  1.118269
# 1    0.729197 -0.647059 -1.256320 -0.166220 -0.718403 -1.054255 -0.669778
# 2   -0.891241 -0.647059 -0.372049  0.902335  2.385097  0.953850  1.042182
# 3   -0.891241  1.117647  1.219639  0.902335 -0.718403 -1.054255 -0.498582
# 4    2.349636  1.117647  2.752375 -2.303330 -0.718403  0.953850  0.395442
# 5   -0.891241 -0.647059 -0.077292 -0.166220 -0.718403 -1.054255 -1.316518
# 6    0.729197  1.117647  1.101736  0.902335  1.350597  0.953850  0.167180
# 7    0.729197 -2.411765  1.101736  0.902335  0.316097  0.953850  0.509572
# 8    2.349636  1.117647  2.280764  0.902335 -0.718403  0.953850  1.460661
# 9    0.729197 -0.647059 -0.666806 -0.166220 -0.718403 -1.054255 -0.574669
# 10   0.729197 -0.647059 -0.666806  0.902335 -0.718403  0.953850  1.004138
# 11  -0.891241 -0.647059  0.512222  0.902335 -0.718403 -1.054255 -0.441517
# ...

# %%
z_score=np.abs(heart_1)

# %%
filtered_entries=(z_score<3).all(axis=1)
heart_final=heart[filtered_entries]
heart_final
# Out:
#      slope_of_peak_exercise_st_segment  thal  resting_blood_pressure  \
# 0                                    1     1                     128
# 1                                    2     1                     110
# 2                                    1     1                     125
# 3                                    1     2                     152
# 4                                    3     2                     178
# 5                                    1     1                     130
# 6                                    2     2                     150
# 7                                    2     0                     150
# 8                                    3     2                     170
# 9                                    2     1                     120
# 10                                   2     1                     120
# 11                                   1     1                     140
# 12                                   1     1                     140
# ...

# %%
print(heart_final.shape) # Final Shape of the DataFrame after removing the Outliers from the Features.
print(heart.shape)
# Out:
# (176, 13)
# (180, 13)

# %%
# After Removing Outlier.
sb.distplot(heart_final.serum_cholesterol_mg_per_dl)
# Out:
# <AxesSubplot:xlabel='serum_cholesterol_mg_per_dl', ylabel='Density'>

# %%
sb.distplot(heart_final.oldpeak_eq_st_depression)
# Out:
# <AxesSubplot:xlabel='oldpeak_eq_st_depression', ylabel='Density'>

# %%
sb.distplot(heart_final.num_major_vessels)
# Out:
# <AxesSubplot:xlabel='num_major_vessels', ylabel='Density'>

# %%
sb.set_style("whitegrid")
sb.distplot(heart_final)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
X=heart_final.iloc[:,:-1]
y=heart_final.heart_disease_present

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score,classification_report,f1_score,ConfusionMatrixDisplay,confusion_matrix,precision_recall_curve,roc_auc_score,plot_roc_curve,plot_precision_recall_curve,RocCurveDisplay,roc_curve

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.4,random_state=3)

# %%
X_train.shape
# Out:
# (105, 12)

# %%
y_train.shape
# Out:
# (105,)

# %% [markdown]
# # MODELS

# %% [markdown]
# ## 1.Logiostic Regression.

# %%
from sklearn.linear_model import LogisticRegression

# %%
model=LogisticRegression()

# %%
model.fit(X_train,y_train)
y_predict=model.predict(X_test)
accuracy_score(y_test,y_predict)
# Out:
# 0.8309859154929577

# %%
pd.crosstab(y_test,y_predict)
# Out:
# col_0                   0   1
# heart_disease_present
# 0                      35   3
# 1                       9  24

# %%
print("Accuracy on training set: %f" %model.score(X_train,y_train))
print("Accuracy on test set: %f" %model.score(X_test,y_test))
# Out:
# Accuracy on training set: 0.809524
# Accuracy on test set: 0.830986

# %% [markdown]
# ## 2.Random Forest Classifier.

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.45,random_state=5)

# %%
model=RandomForestClassifier(max_features='log2',max_depth=200,n_estimators=800,min_samples_split=2,random_state=5)
model.fit(X_train,y_train)
y_predict=model.predict(X_test)
accuracy_score(y_test,y_predict)
# Out:
# 0.7547169811320755

# %%
pd.crosstab(y_test,y_predict)
# Out:
# col_0                   0   1
# heart_disease_present
# 0                      38  10
# 1                      10  22

# %%
print("Accuracy on training set: %f" %model.score(X_train,y_train))
print("Accuracy on test set: %f" %model.score(X_test,y_test))
# Out:
# Accuracy on training set: 1.000000
# Accuracy on test set: 0.750000

# %% [markdown]
# ## FEATURE_IMPORTANCES

# %%
model.feature_importances_
# Out:
# array([0.06512514, 0.17925167, 0.05786273, 0.09360529, 0.12861183,
#        0.02626552, 0.07337595, 0.09327698, 0.04727824, 0.0759402 ,
#        0.09438961, 0.06501684])

# %%
pd.DataFrame(model.feature_importances_,index= X.columns).sort_values(0,ascending=False)
# Out:
#                                           0
# thal                               0.179252
# num_major_vessels                  0.128612
# max_heart_rate_achieved            0.094390
# chest_pain_type                    0.093605
# oldpeak_eq_st_depression           0.093277
# age                                0.075940
# serum_cholesterol_mg_per_dl        0.073376
# slope_of_peak_exercise_st_segment  0.065125
# exercise_induced_angina            0.065017
# resting_blood_pressure             0.057863
# sex                                0.047278
# resting_ekg_results                0.026266

# %%
plt.figure(figsize=(10,8))
sb.heatmap(heart_final.corr(),annot=True,fmt='.0%')
# Out:
# <AxesSubplot:>

# %%
heart_final.drop(['resting_ekg_results'],axis=1,inplace=True)

# %%
X=heart_final.iloc[:,:-1]
y=heart_final.heart_disease_present

# %% [markdown]
# ## Scaling

# %%
from sklearn.preprocessing import scale
heart_scaled=pd.DataFrame(scale(X), columns=X.columns)
heart_scaled
# Out:
#      slope_of_peak_exercise_st_segment      thal  resting_blood_pressure  \
# 0                            -0.887108 -0.632058               -0.185400
# 1                             0.773860 -0.632058               -1.247513
# 2                            -0.887108 -0.632058               -0.362419
# 3                            -0.887108  1.133691                1.230750
# 4                             2.434829  1.133691                2.764913
# 5                            -0.887108 -0.632058               -0.067388
# 6                             0.773860  1.133691                1.112737
# 7                             0.773860 -2.397806                1.112737
# 8                             2.434829  1.133691                2.292863
# 9                             0.773860 -0.632058               -0.657450
# 10                            0.773860 -0.632058               -0.657450
# 11                           -0.887108 -0.632058                0.522675
# ...

# %% [markdown]
# ## Random Forest Model After Feature_Importances.

# %%
X=heart_scaled
#y=heart_scaled.heart_disease_present

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 176 entries, 0 to 175
# Data columns (total 11 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   slope_of_peak_exercise_st_segment  176 non-null    float64
#  1   thal                               176 non-null    float64
#  2   resting_blood_pressure             176 non-null    float64
#  3   chest_pain_type                    176 non-null    float64
#  4   num_major_vessels                  176 non-null    float64
#  5   serum_cholesterol_mg_per_dl        176 non-null    float64
#  6   oldpeak_eq_st_depression           176 non-null    float64
#  7   sex                                176 non-null    float64
#  8   age                                176 non-null    float64
#  9   max_heart_rate_achieved            176 non-null    float64
#  10  exercise_induced_angina            176 non-null    float64
# dtypes: float64(11)
# ...

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=5)

# %%
model=RandomForestClassifier(max_features='log2',max_depth=400,n_estimators=800,min_samples_split=2,random_state=5)
model.fit(X_train,y_train)
y_predict=model.predict(X_test)
accuracy_score(y_test,y_predict)
# Out:
# 0.7547169811320755

# %%
pd.crosstab(y_test,y_predict)
# Out:
# col_0                   0   1
# heart_disease_present
# 0                      27   5
# 1                       8  13

# %%
print("Accuracy on training set: %f" %model.score(X_train,y_train))
print("Accuracy on test set: %f" %model.score(X_test,y_test))
# Out:
# Accuracy on training set: 1.000000
# Accuracy on test set: 0.754717

# %%
print(classification_report(y_test,y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.84      0.81        32
#            1       0.72      0.62      0.67        21
#
#     accuracy                           0.75        53
#    macro avg       0.75      0.73      0.74        53
# weighted avg       0.75      0.75      0.75        53

# %%
f1_score(y_test,y_predict)
# Out:
# 0.6666666666666666

# %%
roc_curve(y_test,y_predict)
# Out:
# (array([0.     , 0.15625, 1.     ]),
#  array([0.        , 0.61904762, 1.        ]),
#  array([2, 1, 0], dtype=int64))

# %%
roc_auc_score(y_test,y_predict)
# Out:
# 0.7313988095238095

# %%
plot_precision_recall_curve(model, X_test, y_test)

# %%
plot_roc_curve(model,X_test,y_test,response_method ='auto')

# %% [markdown]
# ## K-Fold.

# %%
from sklearn.model_selection import cross_val_score # instead of train_test_split
scores = cross_val_score(model,X,y,cv=10,scoring='accuracy') # cv means k-fold
print(scores)
print("Average Accuracy:",scores.mean())
print("Std :",scores.std())
# Out:
# [0.77777778 0.77777778 0.72222222 1.         0.88888889 0.88888889
#  0.82352941 0.76470588 0.70588235 0.82352941]
# Average Accuracy: 0.8173202614379085
# Std : 0.08429155608625596

# %%
model=RandomForestClassifier()
model.fit(X,y)
y_predict=model.predict(X_test)
print(accuracy_score(y_test,y_predict))
# Out:
# 1.0

# %%
print("Accuracy on training set: %f" %model.score(X_train,y_train))
print("Accuracy on test set: %f" %model.score(X_test,y_test))
# Out:
# Accuracy on training set: 1.000000
# Accuracy on test set: 1.000000

# %%
pd.crosstab(y_test,y_predict)
# Out:
# col_0                   0   1
# heart_disease_present
# 0                      32   0
# 1                       0  21

# %%
print(classification_report(y_test,y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        32
#            1       1.00      1.00      1.00        21
#
#     accuracy                           1.00        53
#    macro avg       1.00      1.00      1.00        53
# weighted avg       1.00      1.00      1.00        53

# %% [markdown]
# ### Model Evaluations.

# %%
f1_score(y_test,y_predict)
# Out:
# 1.0

# %%
roc_auc_score(y_test,y_predict)
# Out:
# 1.0

# %%
roc_curve(y_test,y_predict)
# Out:
# (array([0., 0., 1.]), array([0., 1., 1.]), array([2, 1, 0], dtype=int64))

# %%
plot_roc_curve(model,X_test,y_test,response_method ='auto')

# %%
precision_recall_curve(y_test,y_predict)
# Out:
# (array([1., 1.]), array([1., 0.]), array([1], dtype=int64))

# %%
plot_precision_recall_curve(model, X_test, y_test)
